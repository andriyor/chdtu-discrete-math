# %%
import networkx as nx
from networkx.algorithms.flow import edmonds_karp
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()
G.add_edge('X1','X2', weight=7)
G.add_edge('X1','X3', weight=8)
G.add_edge('X1','X4', weight=14)
G.add_edge('X2','X3', weight=13)
G.add_edge('X2','X4', weight=12)
G.add_edge('X3','X5', weight=5)
G.add_edge('X3','X6', weight=8)
G.add_edge('X4','X2', weight=19)
G.add_edge('X4','X3', weight=3)
G.add_edge('X4','X5', weight=8)
G.add_edge('X5','X6', weight=1)
G.add_edge('X6','X2', weight=26)
nx.draw_circular(G, with_labels=True, font_weight='bold')
nx.dijkstra_path(G,'X1','X6')
# Out:
# ['X1', 'X3', 'X5', 'X6']
